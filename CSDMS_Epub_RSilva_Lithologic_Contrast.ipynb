# %% [markdown]
# ## The shrinking and expanding of basins: insights from a Landscape Evolution Model with high lithological contrast
#
# Authors and Affiliation:
#
# Renato da Silva*,
# Pedro Silvestre*,
# Pedro Val*
#
# *CUNY Queens College - School of Earth and Environmental Sciences
#
# Abstract:
# Landscapes in a transient state can be described as areas that are undergoing topographical and geomorphological adjustments. In tectonically active areas, it is straightforward to interpret and reconstruct topography using transient geomorphic signals based on stream power theory. However, areas without tectonic activity are also rife with topographic transience but lack a clear trigger. Landscapes with heterogeneous lithological substrates present geomorphic signals of an ongoing transient state even when their geological context implies tectonic and climatic quiescence. Here, I propose to investigate the transient landscape response to the exhumation of heterogenous lithology. The main objective of this project is to quantify the influence of lithology on landscape evolution processes in the absence of tectonic activity. I hypothesize that divide asymmetries are created by the differential incision power each basin has at the lithologic transition. The differences are a function of the drainage area and the distance crossed over the resistant rocks. Our work is based on a LandLab simulation in which the synthetic DEM has a rock in its lower (southern) portion that is more resistant to erosion. The boundary conditions were configured so that only the southern part was open to the river system, which resulted in drainages flowing from north to south. The drainage basins was then analyzed from the same base level, controlled by the exhumation of the most resistant rock. Preliminary results indicate that basins with a smaller drainage area are subject to shrinkage processes after the exhumation of resistant rock in their outlet (base level). While the basins that had the largest drainage area gained area via river capture and divide migration, expanding their total area over time and thus shrinking the adjacent basins.
#
# Note: this script was based on the "Stream power, channel steepness, and relief" script, writen by Nicole Gasparini and available at https://github.com/landlab/landscape_metrics_course/blob/main/stream_power_channels_steepness_notebook.ipynb

# %% [markdown]
# ### Introduction
#
# Fluvial landscapes in a transient state show, through time, topographical changes usually related to the underlying geological conditions and geomorphology. These adjustments can be a result of tectonic and/or climatic drivers (Wobus et al., 2006; Kirby & Whipple, 2012) or lithologic drivers (Gallen, 2017; DiBiase et al., 2018). The latter is often associated with tectonic inactive areas, where such adjustments appear to lack an apparent trigger process, making the analysis of landscape evolution difficult (DiBiase et al., 2018). This work is focused on the role of heterogeneous bedrock in erosional processes that drive divide migration in tectonically dead areas. We hypothesize that exhumation of non-uniform lithology (i.e. erodibility) may itself be a driver for subsequent geomorphic adjustments.
#
# In this paper, we will analyze how differences in lithology influence erosional process dynamics in regions where tectonics and climate do not play the main role as drivers for landscape evolution. Our main objective is to quantify how those different rock types impact drainage area exchange between watersheds. The presence of non-uniform lithology generates divide asymmetries, as watersheds of different drainage areas experience different erosion rates at the moment of exhumation. These variations are influenced by drainage area and the extent (or width in a plain view) of the more resistant rock type.
#
# To investigate this hypothesis, we used the LandLab (Hobley et al., 2017; Barnhart et al., 2020) to simulate the evolution of a synthetic landscape, where the southern portion features a more resistant rock. The synthetic grid is configured with closed boundary conditions in the West, North, and East, and open boundary in the South. By doing that, the drainage basins are configured with headwaters in the North and outlets in the South. This setup helps us analyze how the exhumation of different rock types affects the drainage area exchange processes of adjacent watersheds.
#
# Our simulations indicate that smaller watersheds tend to shrink following the exhumation of the more resistant rock. On the other hand, larger drainage basins expand their area through river capture and divide migration processes. These results highlight the effects of lithological contrast and heterogeneity on landscape evolution, particularly in landscapes with quiescent tectonics and climate.

# %% [markdown]
# ### Results
#
# In Figure 1, we show two components of our model focusing on the channel network and drainage basin configuration and the relationship between drainage area and topographic slope across the simulated landscape. Figure 1-a presents a map view of the river network. This visualization highlights the spatial distribution, trunk channels, and main divides developed over the simulated period. The boundary conditions are set up with only the South boundary open to the rivers, thus all river basins flow towards this border. Figure 1-b displays a log-log plot of the drainage area and slope for each of the landscape's core nodes. The blue dots represent the drainage area and corresponding slopes at various locations within the grid. A regression analysis on the log-log plot results in a significant correlation, indicated by a high coefficient of determination (R^2), determining a power-law relationship between these two variables.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# Figure 1 - Synthetic landscape in steady-state. (a) Topographic elevation grid with rivers flowing from North to South and represented by colors. Basins 5, 7, and 8 were analyzed in the next steps. (b) Slope-area data at each point of the landscape in a log-log plot.

# %% [markdown]
# Figure 2 illustrate the morphology features of longitudinal and chi-elevation profiles of a landscape in equilibrium, highlighting the uniform response of slope along different drainage area. The longitudinal profiles plot elevation as a function of distance upstream, and in our case the profiles exhibit typical concave morphology, indicative of landscapes in which erosional processes have adjusted with the local uplift rates, climate, and rock resistance (Figure 2-a). Thus, the concavity of these profiles is evidence of the balance between erosion and sediment transport efficiency across the landscape.  Figure 2-b show chi-elevation profiles, where elevation is plotted against the chi parameter, a metric that integrates the drainage area to better constrain geomorphic signals and parameters. The profiles display straight lines, indicating consistent normalized steepness index across the river network, which is characteristic of landscape in equilibrium. The profiles present high linearity and different rivers collapse at the same level and slope, which means that uplift, climate, and lithological processes are uniform across the landscape.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# Figure 2 - Longitudinal and Chi-elevation profiles. (a) Longitudinal profiles for all rivers of our landscape. (b) Chi-elevation profiles for the same group of rivers.

# %% [markdown]
# We analyze the influence of different lithologies on river profiles, using a landscape model generated after the exhumation of two rock-types, one more resistant than the other (Figure 3). Figure 3-a show the longitudinal profiles, where rivers that cross areas of more resistant rock (K_sp=1.0e-5) before eroding softer rock (K_sp=5.0e-5) presented gentler slopes compared to those restricted to resistant rock.  Figure 3-b display the chi-elevation plots, and again rivers draining predominantly resistant rock presented steeper profiles. Both profiles demonstrates how landscape in transient state modify the river profiles morphology, segmentating each river in areas with different rocks and separating the rivers in two different groups.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# Figure 3 - Longitudinal (a) and Chi-elevation (b) profiles in a transient landscape.

# %% [markdown]
# The sheet presented is a series of geomorphic parameters extracted from three different drainage basins (ID 5, 7, and 8) across four time intervals (0, 100, 200, 300 thousand years, abbreviated as ky). The basin's outlets spatial coordinates are fixed over time, while variables such as drainage area, mean elevation, mean ksn, and mean gradient, varies across different time intervals (Table 1). The drainage area present an increase for basins 5 and 8, and basin 7 is the only one that loses drainage area over time (Figure 4-a).  Figure 4-b shows that the mean elevation decreases over time for all basins, however, basin 7 moves from the lowest to the highest elevation after the exhumation of the resistant rock (100-300 ky).  The mean ksn and mean slope shows a decrease over time for all basins, with basin 7 being an exception at 200 ky and 300 ky, showing a increase of 1.76 from 100-200 ky and 0.22 from 200-300 ky (Figures 4-c and 4-d).

# %%
import pandas as pd

df = pd.read_csv('CSDMS_sheet.csv')
display(df)
# Out:
#     Time [ky]  ID  out_x  out_y  drainage_area  mean_el  mean_ksn  mean_gradient
# 0           0   5  15500    100          27.76    30.39      9.94             27
# 1           0   7  17300    100           3.16    22.49     10.00             28
# 2           0   8  18900    100          17.80    28.54      9.54             25
# 3         100   5  15500    100          29.88    10.43      2.48             11
# 4         100   7  17300    100           2.00    14.35      8.04             21
# 5         100   8  18900    100          18.28    10.51      3.32             11
# 6         200   5  15500    100          31.32     9.46      2.32              8
# 7         200   7  17300    100           1.32    15.29      9.80             23
# 8         200   8  18900    100          18.52     9.76      2.64              8
# 9         300   5  15500    100          31.60     9.39      2.32              8
# 10        300   7  17300    100           1.20    15.97     10.02             24
# ...

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Figure 4 - All plots is refered to basins 5, 7, and 8, and comprises the time interval of 0, 100, 200, and 300 thousand years (ky). (a) Plot with drainage area over time; (b) Plot of mean elevation over time; (c) Plot of mean ksn; (d) Plot of mean gradient (slope).

# %% [markdown]
# ### Discussion
#
# The plot of drainage area and topographic slope for each landscape’s core node show that the observed power-law relationship reflects the equilibrium state in the landscape. Mackin (1948) states that graded rivers present, over the years, slope adjusted with the available discharge only the velocity required for the sediment’s transportation. Thus, the graded profile is a system in equilibrium. In this sense, a landscape in equilibrium is a region where endogenous and exogenous forces are equal (U=E, i.e. uplift is equal to erosion) and, therefore, the variation in elevation of any given point of the channel through time (δz⁄δt) is equal to zero (Kirby & Whipple, 2012).
#
# One way to analyze a landscape in an equilibrium state is by using longitudinal profiles and stream power metrics, such as normalized channel steepness or chi parameter (Kirby & Whipple, 2012; Peifer et al., 2020). In this context, longitudinal profiles will present a concave shape, a feature that is indicative of areas where erosional processes have adjusted with the imposed uplift and climate conditions. The chi parameter is also called the integration method and is characterized by the transformation of the horizontal coordinate of the longitudinal profiles (distance, x) into a variable of chi (Perron & Royden, 2013). This variable is used to plot a new profile, where rivers in equilibrium appear as straight lines (Perron & Royden, 2013; Kirby & Whipple, 2012). Therefore, our results are aligned with these interpretations that highlight an equilibrium state, as we can observe in Figures 2-a and 2-b.
#
# Profiles generated from a transient state are characterized by different linear regression equations, which means that the equation parameters are different and thus the profile is considered a segmented river (Wobus et al., 2006). Figure 3 displays our results related to the profiles in a context with heterogeneous lithology. Rivers that drain areas with both lithologies present a break, which we call knickpoints, related to the contact between the two exhumated lithologies. In this context, rivers that drain only the most resistant lithology have greater slopes. These results show that, at this point, the landscape is in a transient state, in its way to adjust to the newer differences in erodibility and lithology.
#
# Our time interval analysis reveals that watersheds that had greater drainage areas at the moment of the rock-resistant exhumation tend to capture smaller adjacent basins, and thus expand over time. While smaller basins shrink, with drainage divides migrating from north to south, like a zipper closing and strangling the smaller basins, which end up losing area over time. These observations are corroborated by the other variables. The mean elevation shows that the smaller basins generally have higher elevation after the exhumation, which leads to an asymmetry in the drainage divide related to elevation in the river headwaters. This topographic asymmetry, described by Gilbert (1877) and improved by Whipple et al. (2017) and Forte & Whipple (2018), promotes the migration of the divide towards regions of smaller basins (e.g., basin 7), causing them to shrink. Lastly, basins that are shrinking tend to increase their ksn and slope parameters, since resistant lithology becomes the predominant type over time, and thus hinders erosion processes along the river valley. As a consequence, the river incision is concentrated in the main channels, increasing their erosion potential (ksn) and slope.

# %% [markdown]
# ### Conclusions
#
# - Landscapes with heterogeneous lithology present differences in erosion potential, which generates segmented river profiles with knickpoints at lithological contacts. These segmented profiles are diagnostic to transient state, since the landscape is adjusting to new conditions.
#
# - At the moment of the rock-resistant exhumation onwards, larger drainage basins tend to expand their areas via drainage capture and divide migration. These processes leads to the shrinking of smaller basins, increasing their mean elevation and steepness due to the predominance of more resistant lithology.
#
# - As a long-term result, the observed topographic asymmetries near drainage divides promotes expansion processes in larger basins, whereas smaller basins experience shrinking, and increased steepness and elevation. Therefore, we can conclude that differences in lithology erodibility lead to systematic adjustment processes, with which the transient system works to return to a state of equilibrium via drainage capture and divide migration.

# %% [markdown]
# ### References
#
# - Barnhart, K.R., Hutton, E.W.H., Tucker, G.E., M. Gasparini, N., Istanbulluoglu, E., E. J. Hobley, D., J. Lyons, N., Mouchene, M., Siddhartha Nudurupati, S., M. Adams, J., Bandaragoda, C., 2020. Short communication: Landlab v2.0: A software package for Earth surface dynamics. Earth Surf. Dyn. 8, 379–397. https://doi.org/10.5194/ESURF-8-379-2020
# - DiBiase, R.A., Denn, A.R., Bierman, P.R., Kirby, E., West, N., Hidy, A.J., 2018. Stratigraphic control of landscape response to base-level fall, Young Womans Creek, Pennsylvania, USA. Earth Planet. Sci. Lett. 504, 163–173. https://doi.org/https://doi.org/10.1016/j.epsl.2018.10.005
# - Forte, A., Whipple, K.X., 2018. Criteria and Tools for Determining Drainage Divide Stability. Earth Planet. Sci. Lett. 493, 102–117. https://doi.org/10.31223/OSF.IO/ANR29
# - Gallen, S.F., 2018. Lithologic controls on landscape dynamics and aquatic species evolution in post-orogenic mountains. Earth Planet. Sci. Lett. 493, 150–160. https://doi.org/10.1016/J.EPSL.2018.04.029
# - Gilbert, G.K., 1877. Report on the geology of the Henry Mountains, Monograph. Washington, D.C. https://doi.org/10.3133/70039916
# - Hobley, D.E.J., Adams, J.M., Siddhartha Nudurupati, S., Hutton, E.W.H., Gasparini, N.M., Istanbulluoglu, E., Tucker, G.E., 2017. Creative computing with Landlab: An open-source toolkit for building, coupling, and exploring two-dimensional numerical models of Earth-surface dynamics. Earth Surf. Dyn. 5, 21–46. https://doi.org/10.5194/ESURF-5-21-2017
# - Kirby, E., Whipple, K.X., 2012. Expression of active tectonics in erosional landscapes. J. Struct. Geol. https://doi.org/10.1016/j.jsg.2012.07.009
# - Mackin, J.H., 1948. Concept of the graded river. GSA Bull. 59, 463–512. https://doi.org/10.1130/0016-7606(1948)59[463:cotgr]2.0.co;2
# - Peifer, D., Cremon, É.H., Alves, F.C., 2020. Ferramentas modernas para a extração de métricas de gradientes fluviais a partir de MDEs: uma revisão. Rev. Bras. Geomorfol. 21.
# - Perron, J.T., Royden, L., 2013. An integral approach to bedrock river profile analysis. Earth Surf. Process. Landforms 38, 570–576. https://doi.org/10.1002/esp.3302
# - Whipple, K.X., Forte, A.M., DiBiase, R.A., Gasparini, N.M., Ouimet, W.B., 2017. Timescales of landscape response to divide migration and drainage capture: Implications for the role of divide mobility in landscape evolution. J. Geophys. Res. Earth Surf. 122, 248–273. https://doi.org/10.1002/2016JF003973
# - Wobus, C., Whipple, K.X., Kirby, E., Snyder, N., Johnson, J., Spyropolou, K., Crosby, B., Sheehan, D., 2006. Tectonics from topography: Procedures, promise, and pitfalls, in: Special Paper 398: Tectonics, Climate, and Landscape Evolution. Geological Society of America, pp. 55–74. https://doi.org/10.1130/2006.2398(04)

# %%
# Step 1 - importing libraries

import numpy as np
from matplotlib import pyplot as plt

from landlab import RasterModelGrid, imshow_grid
from landlab.components import (
    ChannelProfiler,
    ChiFinder,
    FlowAccumulator,
    SteepnessFinder,
    StreamPowerEroder,
    LinearDiffuser,
)
from landlab.io import write_esri_ascii

# %%
# Step 2 - Make a grid and set boundary conditions

number_of_rows = 50  # number of raster cells in vertical direction (y)
number_of_columns = 100  # number of raster cells in horizontal direction (x)
dxy = 200  # side length of a raster model cell, or resolution [m]

# Below is a raster (square cells) grid, with equal width and height
mg1 = RasterModelGrid((number_of_rows, number_of_columns), dxy)

# Set boundary conditions - only the south side of the grid is open.
# Boolean parameters are sent to function in order of
# east, north, west, south.
mg1.set_closed_boundaries_at_grid_edges(True, True, True, False)

# %%
# Step 3 - initial grid of elevation of zeros with a very small amount of noise

np.random.seed(35)  # seed set so our figures are reproducible
mg1_noise = (np.random.rand(mg1.number_of_nodes) / 1000.0
             )  # initial noise on elevation grid

# set up the elevation on the grid
z1 = mg1.add_zeros("topographic__elevation", at="node")
z1 += mg1_noise

# %%
# Step 4 - Set parameters related to time

tmax = 1e5  # time for the model to run [yr] (Original value was 5E5 yr)
dt = 1000  # time step [yr] (Original value was 100 yr)
total_time = 0  # amount of time the landscape has evolved [yr]
# total_time will increase as you keep running the code.

t = np.arange(0, tmax, dt)  # each of the time steps that the code will run

# %%
# Step 5 - Set parameters for incision and intializing all of the process components

# Creating function create_lithology  
def create_lithology(number_of_rows,number_of_columns, K_sp1, K_sp2):
    """
    Create a lithology array to be used on the StreamPowerEroder function

    Return lithology
    """
    lithology = np.zeros((number_of_rows, number_of_columns))
    
    for row,column in enumerate(lithology):
        if row<=9:
            for i in range(number_of_columns):
                lithology[row,i]=K_sp1
        else:
            for i in range(number_of_columns):
                lithology[row,i]=K_sp2
    return lithology

# Creating lithology variable using create_lithology function
lithology = create_lithology(number_of_rows,number_of_columns,1.0e-5,5.0e-5)

# Original K_sp value is 1e-5
K_sp = 1.0e-5  # units vary depending on m_sp and n_sp
m_sp = 0.5  # exponent on drainage area in stream power equation
n_sp = 1.0  # exponent on slope in stream power equation

frr = FlowAccumulator(mg1)  # intializing flow routing
spr = StreamPowerEroder(mg1, K_sp=K_sp, m_sp=m_sp, n_sp=n_sp,
                        threshold_sp=0.0)  # initializing stream power incision
ld = LinearDiffuser(mg1, linear_diffusivity=0.0025)

theta = m_sp / n_sp
# initialize the component that will calculate channel steepness
sf = SteepnessFinder(mg1, reference_concavity=theta, min_drainage_area=1000.0)
# initialize the component that will calculate the chi index
cf = ChiFinder(mg1,
               min_drainage_area=1000.0,
               reference_concavity=theta,
               use_true_dx=True)

# %%
# Step 6 - Initialize rock uplift rate and running until topographic equilibrium

#  uplift_rate [m/yr] (Original value is 0.0001 m/yr)
uplift_rate = np.ones(mg1.number_of_nodes) * 0.0001

# Running simulation until topographic equilibrium (for 300 Ma)

def running_equilibrium(mg, z, fa, sp, ld, uplift_rate, dt, mg1_noise):
    """
    Run the model until topography reaches the topographic equilibrium.

    Parameters:
    - mg: the grid representing the landscape
    - z: array of elevation values
    - fa: flow accumulator component
    - sp: stream power erosion component
    - ld: linear diffusion component
    - uplift_rate: array of uplift rates
    - dt: time step
    - mg1_noise: noise level in the grid used as a threshold for equilibrium

    Returns:
    - mg: the grid in equilibrium
    """
    zdiffm = 1  # Initial difference must be set to a value greater than any noise threshold

    while zdiffm > np.max(mg1_noise):
        zinit = z.copy()
    
        # Apply uplift
        mg.at_node['topographic__elevation'][mg.core_nodes] += uplift_rate[mg.core_nodes] * dt
    
        # Run the landscape evolution processes
        fa.run_one_step()  # flow accumulator
        sp.run_one_step(dt) # stream power
        ld.run_one_step(dt) # linear diffuser
        
        # Calculate the maximum difference in elevation from the previous step
        zdiffm = np.max(np.abs(zinit - z))

    return mg

mg1 = running_equilibrium(mg1,z1,frr,spr,ld,uplift_rate,dt,mg1_noise)

# %%
# Step 7 - plot figure

imshow_grid(mg1,
            "topographic__elevation",
            grid_units=("m", "m"),
            var_name="Elevation (m)")
title_text = f"$K_{{sp}}$={K_sp}; $time$={total_time} yr; $dx$={dxy} m"
plt.title(title_text)

max_elev = np.max(z1)
print("Maximum elevation is ", np.max(z1))
# Out:
# Maximum elevation is  78.9344235028

# %%
# Step 8 - Plot the slope and area data at each point on the landscape (in log-log space)

# Extracting drainage area and slope
drainage_area = mg1.at_node["drainage_area"][mg1.core_nodes]
steepest_slope = mg1.at_node["topographic__steepest_slope"][mg1.core_nodes]

# Log-transform the data
log_drainage_area = np.log(drainage_area)
log_slope = np.log(steepest_slope)

# Perform linear regression on the log-transformed data
coefficients = np.polyfit(log_drainage_area, log_slope, 1)
p = np.poly1d(coefficients)  # Create a polynomial function with the fit coefficients

# Calculate the R^2 value
slope_predicted = p(log_drainage_area)
r_squared = np.corrcoef(log_slope, slope_predicted)[0, 1] ** 2

# Plot the log-log graph
plt.loglog(drainage_area, steepest_slope, "b.", label='Data')

# Plot the regression line
regression_line = np.exp(slope_predicted)
plt.plot(drainage_area, regression_line, 'r-', label=f'Best Fit: y={coefficients[0]:.2f}x + {coefficients[1]:.2f}, $R^2$={r_squared:.2f}')

# Add labels and title
plt.ylabel("Topographic slope")
plt.xlabel("Drainage area (m^2)")
title_text = f"$K_{{sp}}$={K_sp}; $time$={total_time} yr; $dx$={dxy} m"
plt.title(title_text)

# Add a legend
plt.legend()

# Display the plot
plt.show()

# %%
# Step 9

# profile the largest channels, set initially to find the mainstem channel in the three biggest watersheds
# you can change the number of watersheds, or choose to plot all the channel segments in the watershed that
# have drainage area below the threshold (here we have set the threshold to the area of a grid cell).
prf = ChannelProfiler(mg1,
                      number_of_watersheds=20,
                      main_channel_only=True,
                      minimum_channel_threshold=dxy**2)
prf.run_one_step()

# plot the elevation as a function of distance upstream
plt.figure(1)
title_text = f"$K_{{sp}}$={K_sp}; $time$={total_time} yr; $dx$={dxy} m"
prf.plot_profiles(xlabel='distance upstream (m)',
                  ylabel='elevation (m)',
                  title=title_text)

# plot the location of the channels in map view
plt.figure(2)
prf.plot_profiles_in_map_view()

# slope-area data in just the profiled channels
plt.figure(3)
for i, outlet_id in enumerate(prf.data_structure):
    for j, segment_id in enumerate(prf.data_structure[outlet_id]):
        if j == 0:
            label = "channel {i}".format(i=i + 1)
        else:
            label = '_nolegend_'
        segment = prf.data_structure[outlet_id][segment_id]
        profile_ids = segment["ids"]
        color = segment["color"]
        plt.loglog(
            mg1.at_node["drainage_area"][profile_ids],
            mg1.at_node["topographic__steepest_slope"][profile_ids],
            '.',
            color=color,
            label=label,
        )

plt.legend(loc="lower left")
plt.xlabel("drainage area (m^2)")
plt.ylabel("channel slope [m/m]")
title_text = f"$K_{{sp}}$={K_sp}; $time$={total_time} yr; $dx$={dxy} m"
plt.title(title_text)
# Out:
# Text(0.5, 1.0, '$K_{sp}$=1e-05; $time$=0 yr; $dx$=200 m')

# %%
# Step 10

# calculate the chi index
cf.calculate_chi()

# chi-elevation plots in the profiled channels
plt.figure(4)

for i, outlet_id in enumerate(prf.data_structure):
    for j, segment_id in enumerate(prf.data_structure[outlet_id]):
        if j == 0:
            label = "channel {i}".format(i=i + 1)
        else:
            label = '_nolegend_'
        segment = prf.data_structure[outlet_id][segment_id]
        profile_ids = segment["ids"]
        color = segment["color"]
        plt.plot(
            mg1.at_node["channel__chi_index"][profile_ids],
            mg1.at_node["topographic__elevation"][profile_ids],
            color=color,
            label=label,
        )

plt.xlabel("chi index (m)")
plt.ylabel("elevation (m)")
plt.legend(loc="lower right")
title_text = f"$K_{{sp}}$={K_sp}; $time$={total_time} yr; $dx$={dxy} m; concavity={theta}"
plt.title(title_text)

# chi map
plt.figure(5)
imshow_grid(
    mg1,
    "channel__chi_index",
    grid_units=("m", "m"),
    var_name="Chi index (m)",
    cmap="jet",
)
title_text = f"$K_{{sp}}$={K_sp}; $time$={total_time} yr; $dx$={dxy} m; concavity={theta}"
plt.title(title_text)
# Out:
# Text(0.5, 1.0, '$K_{sp}$=1e-05; $time$=0 yr; $dx$=200 m; concavity=0.5')

# %%
# Step 11

# calculate channel steepness
sf.calculate_steepnesses()

# plots of steepnes vs. distance upstream in the profiled channels
plt.figure(6)

for i, outlet_id in enumerate(prf.data_structure):
    for j, segment_id in enumerate(prf.data_structure[outlet_id]):
        if j == 0:
            label = "channel {i}".format(i=i + 1)
        else:
            label = '_nolegend_'
        segment = prf.data_structure[outlet_id][segment_id]
        profile_ids = segment["ids"]
        distance_upstream = segment["distances"]
        color = segment["color"]
        plt.plot(
            distance_upstream,
            mg1.at_node["channel__steepness_index"][profile_ids],
            'x',
            color=color,
            label=label,
        )

plt.xlabel("distance upstream (m)")
plt.ylabel("steepness index")
plt.legend(loc="upper left")
plt.title(
    f"$K_{{sp}}$={K_sp}; $time$={total_time} yr; $dx$={dxy} m; concavity={theta}"
)

# channel steepness map
plt.figure(7)
imshow_grid(
    mg1,
    "channel__steepness_index",
    grid_units=("m", "m"),
    var_name="Steepness index ",
    cmap="jet",
)
title_text = ("$K_{sp}$=" + str(K_sp) + "; $time$=" + str(total_time) +
              "yr; $dx$=" + str(dxy) + "m" + "; concavity=" + str(theta))
plt.title(
    f"$K_{{sp}}$={K_sp}; $time$={total_time} yr; $dx$={dxy} m; concavity={theta}"
)
# Out:
# Text(0.5, 1.0, '$K_{sp}$=1e-05; $time$=0 yr; $dx$=200 m; concavity=0.5')

# %%
# Step 12 - Export data generated so far

timestep_file = '0'
write_file_name = 'your_file_path/Data_file_' + timestep_file + 'k_ky_'

write_esri_ascii(write_file_name + 'topographic__elevation.txt', mg1, 'topographic__elevation')
write_esri_ascii(write_file_name + 'drainage_area.txt', mg1, 'drainage_area')
write_esri_ascii(write_file_name + 'topographic__steepest_slope.txt', mg1, 'topographic__steepest_slope')
write_esri_ascii(write_file_name + 'channel__steepness_index.txt', mg1, 'channel__steepness_index')
write_esri_ascii(write_file_name + 'channel__chi_index.txt', mg1, 'channel__chi_index')

# %%
# Step 13 - Using different lithologies

# Creating lithology variable using create_lithology function
lithology = create_lithology(number_of_rows,number_of_columns,1.0e-5,5.0e-5)

# Updating StreamPowerEroder component
spr = StreamPowerEroder(mg1, K_sp=lithology, m_sp=m_sp, n_sp=n_sp,
                        threshold_sp=0.0)  # initializing stream power incision

# for loop landscape evolution
for ti in t:
    z1[mg1.
       core_nodes] += uplift_rate[mg1.core_nodes] * dt  # uplift the landscape
    frr.run_one_step()  # route flow
    spr.run_one_step(dt)  # fluvial incision
    ld.run_one_step(dt) # linear diffusion
    total_time += dt  # update time keeper
    print(total_time)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000

# %%
# Step 14 - plot figure

imshow_grid(mg1,
            "topographic__elevation",
            grid_units=("m", "m"),
            var_name="Elevation (m)")
title_text = f"$K_{{sp}}$={K_sp}; $time$={total_time} yr; $dx$={dxy} m"
plt.title(title_text)

max_elev = np.max(z1)
print("Maximum elevation is ", np.max(z1))
# Out:
# Maximum elevation is  39.039069193

# %%
# Step 15 - All other plots

# Plot 1 - Slope Area Data
# Extracting drainage area and slope
drainage_area = mg1.at_node["drainage_area"][mg1.core_nodes]
steepest_slope = mg1.at_node["topographic__steepest_slope"][mg1.core_nodes]

# Log-transform the data
log_drainage_area = np.log(drainage_area)
log_slope = np.log(steepest_slope)

# Perform linear regression on the log-transformed data
coefficients = np.polyfit(log_drainage_area, log_slope, 1)
p = np.poly1d(coefficients)  # Create a polynomial function with the fit coefficients

# Calculate the R^2 value
slope_predicted = p(log_drainage_area)
r_squared = np.corrcoef(log_slope, slope_predicted)[0, 1] ** 2

# Plot the log-log graph
plt.figure(1)
plt.loglog(drainage_area, steepest_slope, "b.", label='Data')

# Plot the regression line
regression_line = np.exp(slope_predicted)
plt.plot(drainage_area, regression_line, 'r-', label=f'Best Fit: y={coefficients[0]:.2f}x + {coefficients[1]:.2f}, $R^2$={r_squared:.2f}')

# Add labels and title
plt.ylabel("Topographic slope")
plt.xlabel("Drainage area (m^2)")
title_text = f"$K_{{sp}}$={K_sp}; $time$={total_time} yr; $dx$={dxy} m"
plt.title(title_text)

# Add a legend
plt.legend()

# Display the plot
plt.show()

# Plot 2 - Channel Profiles
prf = ChannelProfiler(mg1,
                      number_of_watersheds=20,
                      main_channel_only=True,
                      minimum_channel_threshold=dxy**2)
prf.run_one_step()

# plot the elevation as a function of distance upstream
plt.figure(2)
title_text = f"$K_{{sp}}$={K_sp}; $time$={total_time} yr; $dx$={dxy} m"
prf.plot_profiles(xlabel='distance upstream (m)',
                  ylabel='elevation (m)',
                  title=title_text)

# plot the location of the channels in map view
plt.figure(3)
prf.plot_profiles_in_map_view()

# slope-area data in just the profiled channels
plt.figure(4)
for i, outlet_id in enumerate(prf.data_structure):
    for j, segment_id in enumerate(prf.data_structure[outlet_id]):
        if j == 0:
            label = "channel {i}".format(i=i + 1)
        else:
            label = '_nolegend_'
        segment = prf.data_structure[outlet_id][segment_id]
        profile_ids = segment["ids"]
        color = segment["color"]
        plt.loglog(
            mg1.at_node["drainage_area"][profile_ids],
            mg1.at_node["topographic__steepest_slope"][profile_ids],
            '.',
            color=color,
            label=label,
        )

plt.legend(loc="lower left")
plt.xlabel("drainage area (m^2)")
plt.ylabel("channel slope [m/m]")
title_text = f"$K_{{sp}}$={K_sp}; $time$={total_time} yr; $dx$={dxy} m"
plt.title(title_text)

# Plot 3 - Chi plot and Chi map
# calculate the chi index
cf.calculate_chi()

# chi-elevation plots in the profiled channels
plt.figure(5)

for i, outlet_id in enumerate(prf.data_structure):
    for j, segment_id in enumerate(prf.data_structure[outlet_id]):
        if j == 0:
            label = "channel {i}".format(i=i + 1)
        else:
            label = '_nolegend_'
        segment = prf.data_structure[outlet_id][segment_id]
        profile_ids = segment["ids"]
        color = segment["color"]
        plt.plot(
            mg1.at_node["channel__chi_index"][profile_ids],
            mg1.at_node["topographic__elevation"][profile_ids],
            color=color,
            label=label,
        )

plt.xlabel("chi index (m)")
plt.ylabel("elevation (m)")
plt.legend(loc="lower right")
title_text = f"$K_{{sp}}$={K_sp}; $time$={total_time} yr; $dx$={dxy} m; concavity={theta}"
plt.title(title_text)

# chi map
plt.figure(6)
imshow_grid(
    mg1,
    "channel__chi_index",
    grid_units=("m", "m"),
    var_name="Chi index (m)",
    cmap="jet",
)
title_text = f"$K_{{sp}}$={K_sp}; $time$={total_time} yr; $dx$={dxy} m; concavity={theta}"
plt.title(title_text)

# Plot 4 - Channel Steepness plots
# calculate channel steepness
sf.calculate_steepnesses()

# plots of steepnes vs. distance upstream in the profiled channels
plt.figure(7)

for i, outlet_id in enumerate(prf.data_structure):
    for j, segment_id in enumerate(prf.data_structure[outlet_id]):
        if j == 0:
            label = "channel {i}".format(i=i + 1)
        else:
            label = '_nolegend_'
        segment = prf.data_structure[outlet_id][segment_id]
        profile_ids = segment["ids"]
        distance_upstream = segment["distances"]
        color = segment["color"]
        plt.plot(
            distance_upstream,
            mg1.at_node["channel__steepness_index"][profile_ids],
            'x',
            color=color,
            label=label,
        )

plt.xlabel("distance upstream (m)")
plt.ylabel("steepness index")
plt.legend(loc="upper left")
plt.title(
    f"$K_{{sp}}$={K_sp}; $time$={total_time} yr; $dx$={dxy} m; concavity={theta}"
)

# channel steepness map
plt.figure(8)
imshow_grid(
    mg1,
    "channel__steepness_index",
    grid_units=("m", "m"),
    var_name="Steepness index ",
    cmap="jet",
)
title_text = ("$K_{sp}$=" + str(K_sp) + "; $time$=" + str(total_time) +
              "yr; $dx$=" + str(dxy) + "m" + "; concavity=" + str(theta))
plt.title(
    f"$K_{{sp}}$={K_sp}; $time$={total_time} yr; $dx$={dxy} m; concavity={theta}"
)

# %%
# Step 16 - Export data generated so far

timestep_file = 'XXX' # write here the timestep you are analyzing (e.g., '100' for 100 thousand years)
write_file_name = 'your_file_path/Data_file_' + timestep_file + 'k_ky_'

write_esri_ascii(write_file_name + 'topographic__elevation.txt', mg1, 'topographic__elevation')
write_esri_ascii(write_file_name + 'drainage_area.txt', mg1, 'drainage_area')
write_esri_ascii(write_file_name + 'topographic__steepest_slope.txt', mg1, 'topographic__steepest_slope')
write_esri_ascii(write_file_name + 'channel__steepness_index.txt', mg1, 'channel__steepness_index')
write_esri_ascii(write_file_name + 'channel__chi_index.txt', mg1, 'channel__chi_index')
